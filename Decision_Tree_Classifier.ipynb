# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder

# %%
data=pd.read_csv("heart.csv")
data
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
print(data.head)
print(data.columns)
# Out:
# <bound method NDFrame.head of       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# ...

# %%
print(data.isnull().sum())
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
X=data[["age", "cp", "chol", "thalach", "oldpeak", "ca"]]
X=X.astype(int)
y=data["target"]
print(X)
# Out:
#       age  cp  chol  thalach  oldpeak  ca
# 0      52   0   212      168        1   2
# 1      53   0   203      155        3   0
# 2      70   0   174      125        2   0
# 3      61   0   203      161        0   1
# 4      62   0   294      106        1   3
# ...   ...  ..   ...      ...      ...  ..
# 1020   59   1   221      164        0   0
# 1021   60   0   258      141        2   1
# 1022   47   0   275      118        1   1
# 1023   50   0   254      159        0   0
# 1024   54   0   188      113        1   1
#
# [1025 rows x 6 columns]

# %%
model=DecisionTreeClassifier()
model.fit(X, y)
# Out:
# DecisionTreeClassifier()

# %%
age=int(input("Enter Age:"))
cp=int(input("Enter chest pain:"))
chol=int(input("Enter your Cholesterol level:"))
thalach=int(input("Enter maximum heart rate achieved:"))
oldpeak=int(input("Enter your oldpeak:"))
ca=int(input("Enter No of major vessels:"))
test_patient=pd.DataFrame({"age":[age], "cp":[cp], "chol":[chol], "thalach":[thalach], "oldpeak":[oldpeak], "ca":[ca]})

prediction=model.predict(test_patient)
print("Predicted Result:",prediction[0])
# Out:
# Enter Age: 43
# Enter chest pain: 1
# Enter your Cholesterol level: 245
# Enter maximum heart rate achieved: 143
# Enter your oldpeak: 3
# Enter No of major vessels: 0
# Predicted Result: 1

# %%
if prediction[0]==1:
    print("The Patient has Heart Disease")
else:
    print("The Patient has no Heart Disease")
# Out:
# The Patient has Heart Disease
