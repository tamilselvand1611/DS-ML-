# %%
import pandas as pd

# %%
data=pd.read_csv("hospital data analysis.csv")
data
# Out:
#      Patient_ID  Age  Gender          Condition                  Procedure  \
# 0             1   45  Female      Heart Disease                Angioplasty
# 1             2   60    Male           Diabetes            Insulin Therapy
# 2             3   32  Female      Fractured Arm           X-Ray and Splint
# 3             4   75    Male             Stroke     CT Scan and Medication
# 4             5   50  Female             Cancer   Surgery and Chemotherapy
# ..          ...  ...     ...                ...                        ...
# 979         996   68    Male       Hypertension  Medication and Counseling
# 980         997   45  Female       Appendicitis               Appendectomy
# 981         998   40    Male      Fractured Leg  Cast and Physical Therapy
# 982         999   78  Female       Heart Attack    Cardiac Catheterization
# 983        1000   25    Male  Allergic Reaction      Epinephrine Injection
#
#       Cost  Length_of_Stay Readmission    Outcome  Satisfaction
# ...

# %%
d={"Name":["Tamil","Gowtham","Nithish","Aakash","Hiran"],"Age":[21,18,15,20,5]}

# %%
c=pd.DataFrame(d)
c
# Out:
#       Name  Age
# 0    Tamil   21
# 1  Gowtham   18
# 2  Nithish   15
# 3   Aakash   20
# 4    Hiran    5

# %%
f=c.to_csv("Bro.csv")

# %%
data=pd.read_csv("Bro.csv")
data
# Out:
#    Unnamed: 0     Name  Age
# 0           0    Tamil   21
# 1           1  Gowtham   18
# 2           2  Nithish   15
# 3           3   Aakash   20
# 4           4    Hiran    5

# %%
print(data["Age"])
# Out:
# 0    21
# 1    18
# 2    15
# 3    20
# 4     5
# Name: Age, dtype: int64

# %%
print(data["Name"])
# Out:
# 0      Tamil
# 1    Gowtham
# 2    Nithish
# 3     Aakash
# 4      Hiran
# Name: Name, dtype: object

# %%
print(data["Name"],data["Age"])
# Out:
# 0      Tamil
# 1    Gowtham
# 2    Nithish
# 3     Aakash
# 4      Hiran
# Name: Name, dtype: object 0    21
# 1    18
# 2    15
# 3    20
# 4     5
# Name: Age, dtype: int64

# %%
print(data.loc[0:1,["Name","Age"]])
# Out:
#       Name  Age
# 0    Tamil   21
# 1  Gowtham   18

# %%
print(data.loc[:,["Name","Age"]])
# Out:
#       Name  Age
# 0    Tamil   21
# 1  Gowtham   18
# 2  Nithish   15
# 3   Aakash   20
# 4    Hiran    5

# %%
data={"Name":["Ram","Sai","Ravi"],
      "Age":[20,21,19],
      "Marks":[85,90,88]}
data
# Out:
# {'Name': ['Ram', 'Sai', 'Ravi'], 'Age': [20, 21, 19], 'Marks': [85, 90, 88]}

# %%
df=pd.DataFrame(data)
df.to_csv("data.csv")
print(df)
# Out:
#    Name  Age  Marks
# 0   Ram   20     85
# 1   Sai   21     90
# 2  Ravi   19     88

# %%
df=pd.read_csv("data.csv")
print(df.head())
# Out:
#    Unnamed: 0  Name  Age  Marks
# 0           0   Ram   20     85
# 1           1   Sai   21     90
# 2           2  Ravi   19     88

# %%
print(df.tail())
# Out:
#    Unnamed: 0  Name  Age  Marks
# 0           0   Ram   20     85
# 1           1   Sai   21     90
# 2           2  Ravi   19     88

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  3 non-null      int64
#  1   Name        3 non-null      object
#  2   Age         3 non-null      int64
#  3   Marks       3 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 228.0+ bytes
# None

# %%
print(df.describe())
# Out:
#        Unnamed: 0   Age      Marks
# count         3.0   3.0   3.000000
# mean          1.0  20.0  87.666667
# std           1.0   1.0   2.516611
# min           0.0  19.0  85.000000
# 25%           0.5  19.5  86.500000
# 50%           1.0  20.0  88.000000
# 75%           1.5  20.5  89.000000
# max           2.0  21.0  90.000000

# %%
print(df[df["Marks"]>85])
# Out:
#    Unnamed: 0  Name  Age  Marks
# 1           1   Sai   21     90
# 2           2  Ravi   19     88

# %%
print(df[df["Age"]<20])
# Out:
#    Unnamed: 0  Name  Age  Marks
# 2           2  Ravi   19     88

# %%
data={"Department":["CSE","CSE","IT","IT"],
      "Salary":[50000,60000,70000,80000]}
data
# Out:
# {'Department': ['CSE', 'CSE', 'IT', 'IT'],
#  'Salary': [50000, 60000, 70000, 80000]}

# %%
df=pd.DataFrame(data)

# %%
print(df.groupby("Department").mean())
# Out:
#              Salary
# Department
# CSE         55000.0
# IT          75000.0

# %%
data={"Name":["Tamil","Gowtham","Aakash","Nithish","Hiran Pranav"]}
df=pd.DataFrame(data)
df["Department"]=[None,"AI-DS","IT","BIO","LKG"]
df["City"]=["Mumbai",None,"Chennai",None,"Bangalore"]
df = df.fillna("Unknown")
print(df)
# Out:
#            Name Department       City
# 0         Tamil    Unknown     Mumbai
# 1       Gowtham      AI-DS    Unknown
# 2        Aakash         IT    Chennai
# 3       Nithish        BIO    Unknown
# 4  Hiran Pranav        LKG  Bangalore

# %%
data={"Name":["Tamil","Gowtham","Aakash","Nithish","Hiran Pranav"]}
df=pd.DataFrame(data)
df["Department"]=[None,"AI-DS","IT","BIO","LKG"]
df["City"]=["Mumbai",None,"Chennai",None,"Bangalore"]
df["City"]=df["City"].fillna("Not Available")
df
# Out:
#            Name Department           City
# 0         Tamil       None         Mumbai
# 1       Gowtham      AI-DS  Not Available
# 2        Aakash         IT        Chennai
# 3       Nithish        BIO  Not Available
# 4  Hiran Pranav        LKG      Bangalore

# %%
data = {"Name": ["Tamil", "", "Gowtham"], "City": ["Chennai", "Salem", ""]}
df = pd.DataFrame(data)
df = df.replace("", "Unknown")
print(df)
# Out:
#       Name     City
# 0    Tamil  Chennai
# 1  Unknown    Salem
# 2  Gowtham  Unknown
